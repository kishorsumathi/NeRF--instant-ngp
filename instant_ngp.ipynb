# %%
from google.colab import drive
drive.mount('/content/drive')

# !apt-get install \
    cmake \
    libgoogle-glog-dev \
    libgflags-dev \
    libatlas-base-dev \
    libeigen3-dev \
    libsuitesparse-dev \
    libboost-program-options-dev \
    libboost-filesystem-dev \
    libboost-graph-dev \
    libboost-system-dev \
    libboost-test-dev \
    libfreeimage-dev \
    libmetis-dev \
    libglew-dev \
    qtbase5-dev \
    libqt5opengl5-dev \
    libcgal-dev

# !wget https://github.com/camenduru/instant-ngp-colab/releases/download/v1.0/ceres-solver.zip
# !unzip /content/ceres-solver.zip -d ceres-solver

# !cp -r /content/ceres-solver/lib/. /usr/local/lib
# !chmod 755 /content/ceres-solver/bin/colmap
# !cp -r /content/ceres-solver/bin/. /usr/local/bin

# !wget https://github.com/camenduru/instant-ngp-colab/releases/download/v1.0/instant-ngp.zip
# !unzip /content/instant-ngp.zip -d instant-ngp

# !pip install commentjson huggingface-hub
# %cd /content/instant-ngp
import os
from huggingface_hub import create_repo, upload_folder
# Out:
# Mounted at /content/drive
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-filesystem-dev is already the newest version (1.71.0.0ubuntu2).
# libboost-filesystem-dev set to manually installed.
# libboost-program-options-dev is already the newest version (1.71.0.0ubuntu2).
# libboost-program-options-dev set to manually installed.
# libboost-system-dev is already the newest version (1.71.0.0ubuntu2).
# libboost-system-dev set to manually installed.
# libatlas-base-dev is already the newest version (3.10.3-8ubuntu7).
# libboost-graph-dev is already the newest version (1.71.0.0ubuntu2).
# libboost-graph-dev set to manually installed.
# libboost-test-dev is already the newest version (1.71.0.0ubuntu2).
# libboost-test-dev set to manually installed.
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# qtbase5-dev is already the newest version (5.12.8+dfsg-0ubuntu2.1).
# qtbase5-dev set to manually installed.
# ...

# %%
scene_path = "/content/instant-ngp/data/nerf/fox" #@param {type:"string"}
train_path = "/content/train"
if not os.path.isdir(scene_path):
  raise NotADirectoryError(scene_path)
# !rm -rf {train_path}
# !mkdir {train_path}
# !cp -r {scene_path}/. /content/train
transforms_path = os.path.join(train_path, f"transforms.json")
# !python ./scripts/colmap2nerf.py --colmap_matcher exhaustive --run_colmap --aabb_scale 4 --images {train_path} --out {transforms_path}

train_steps = 4000  #@param {type:"integer"}
snapshot_path = os.path.join(train_path, f"{train_steps}.msgpack")
# !python ./scripts/run.py --scene {train_path} --mode nerf --n_steps {train_steps} --save_snapshot {snapshot_path}
# Out:
# running colmap with:
# 	db=colmap.db
# 	images="/content/train"
# 	sparse=colmap_sparse
# 	text=colmap_text
# warning! folders 'colmap_sparse' and 'colmap_text' will be deleted/replaced. continue? (Y/n)Y
# ==== running: colmap feature_extractor --ImageReader.camera_model OPENCV --ImageReader.camera_params "" --SiftExtraction.estimate_affine_shape=true --SiftExtraction.domain_size_pooling=true --ImageReader.single_camera 1 --database_path colmap.db --image_path "/content/train"
# colmap: error while loading shared libraries: libGLEW.so.2.0: cannot open shared object file: No such file or directory
# FATAL: command failed
# 14:30:43 INFO     Loading NeRF dataset from
# 14:30:43 INFO       /content/train/transforms.json
# 14:30:43 WARNING    /content/train/base_cam.json does not contain any frames. Skipping.
# ...

# %% [markdown]
# ## VIDEO

# %%
video_camera_path = os.path.join(scene_path, "base_cam.json")
if not os.path.isfile(video_camera_path):
  raise FileNotFoundError(video_camera_path)

# %%
video_n_seconds = 5 #@param {type:"integer"}
video_fps = 25 #@param {type:"integer"}
width = 720 #@param {type:"integer"}
height = 720 #@param {type:"integer"}
output_video_path = os.path.join(scene_path, "output_video.mp4")

# !python scripts/run.py --scene {train_path} --mode nerf --load_snapshot {snapshot_path} --video_camera_path {video_camera_path} --video_n_seconds 2 --video_fps 25 --width 720 --height 720 --video_output {output_video_path}
print(f"Generated video saved to:\n{output_video_path}")
# Out:
# 14:33:08 INFO     Loading NeRF dataset from
# 14:33:08 INFO       /content/train/transforms.json
# 14:33:08 WARNING    /content/train/base_cam.json does not contain any frames. Skipping.
# ...
